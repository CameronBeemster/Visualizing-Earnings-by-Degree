# %%
import pandas as pd
import matplotlib as plt

# %%
# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')
recent_grads.iloc[:1]
# Out:
#    Rank  Major_code                  Major   Total     Men  Women  \
# 0     1        2419  PETROLEUM ENGINEERING  2339.0  2057.0  282.0
#
#   Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  \
# 0    Engineering    0.120564           36      1976      ...              270
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 0          1534               364            193
#
# [1 rows x 21 columns]

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = len(recent_grads.index)
recent_grads = recent_grads.dropna()

# %%
cleaned_data_count = len(recent_grads.index)

# %%
print(raw_data_count, cleaned_data_count)
# Out:
# 173 172

# %%
ax1 = recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax1.set_xlim(0)
# Out:
# (0, 5000.0)

# %%
ax2 = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax2.set_xlim(0)
# Out:
# (0, 5000.0)

# %%
ax3 = recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax3.set_xlim(0)
# Out:
# (0, 300000.0)

# %%
ax4 = recent_grads.plot(x='ShareWomen', y='Median', kind='scatter')
ax4.set_xlim(0,1.0)
# Out:
# (0, 1.0)

# %%
ax5 = recent_grads.plot(x='Men',y='Median', kind='scatter')
ax5.set_xlim(0)
# Out:
# (0, 200000.0)

# %%
ax6 = recent_grads.plot(x='Women', y='Median', kind='scatter')
ax6.set_xlim(0)
# Out:
# (0, 350000.0)

# %% [markdown]
# ## Exploration
#
# __Do students in more popular majors make more money?__
#
# Looking at the last two plots _ax5_ and _ax6_, there is no evidence that the students in more popular majors (the majors with a higher number of male/female students) make more money. In fact, based on these graphs, it appears that only the students in the least popular majors have the higher earning potential.
#
# __Do students that majored in subjects that were majority female make more money?__
#
# In plot _ax4_, there seems to be a weak, negative correlation between the share of women in the relative major and median salary. In other words, as the female percentage of a major increases there is a slight decrease in the median salary. The correlation appears to be weak, although there is a noticable trend.
#
# __Is there any link between the number of full-time employees and median salary?__
#
# The distribution of data in plot _ax3_ shows that there is no link between the number of full-time students and median salary. This has to do with the fact that less full-time students may imply a less popular major and a smaller sample size. This can artificially inflate or deflate medians. So, all the data points closer to zero full-time employees with high median salaries could just be due to random chance.

# %%
hist1 = recent_grads['Sample_size'].hist(bins=50)

# %%
hist2 = recent_grads['Median'].hist(bins=20)

# %%
hist3 = recent_grads['Employed'].hist(bins=20)

# %%
hist4 = recent_grads['Full_time'].hist(bins=20)

# %%
hist5 = recent_grads['ShareWomen'].hist(bins=20)

# %%
hist6 = recent_grads['Unemployment_rate'].hist(bins=20)

# %%
hist7 = recent_grads['Men'].hist(bins=50)

# %%
hist8 = recent_grads['Women'].hist(bins=50)

# %% [markdown]
# ## Exploration
#
# __What percent of majors are predominantly male? Predominantly female?__
#
# Looking at _hist5_, 74 out of 172 majors are predominantly male. So, around 43% of the majors in this dataset are mostly male. This means that 98 out of 172, or around 57%, of the majors are mostly female.
#
# __What's the most common median salary range?__
#
# The most common median salary range is between $30,000 and $35,000. This range has more than double the frequency as the next most common median salary range ($40,000-$45,000)

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size','Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd89f0d1ef0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd89efb2470>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Full_time','Part_time','Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd896f72780>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd896cd0668>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Total','Unemployment_rate','Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd896b26c88>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd8967e25f8>]], dtype=object)

# %% [markdown]
# ## Exploration
#
# The scatter plots displaying _Full time_, _Part time_, and _Total_ graduates with _Unemployment rate_ gives an insight into the likelihood of employment after graduation. It appears the three of these graphs follow the same pattern - the more students a program has, the more likely that 5-10% gradutes will experience unemployment.
#
# The unemployment rate between 2010 and 2012 hovered around 10%, which is why the relationship between _Total_ graduates and _Unemployment rate_ trends in the range of 5-10%. It is likely the more graduates of a specifc major there were, the more saturated the market was for those graduates, and thus a 5-10% unemployment makes sense.
#
# The majors with less graduates gives another insight, as well. Programs with a small number of graduates can have anywhere between a ~0% or ~20% unemployment rate. The reason behind this could be that these smaller programs are undesirable because they are very challenging (higher median salary) or very niche (lower median salary).

# %%
top10_sharewomen = recent_grads[:10].plot.bar(x='Major',y='ShareWomen')

# %%
last10_sharewomen = recent_grads[-11:-1].plot.bar(x='Major', y='ShareWomen')

# %%
top10_unemp = recent_grads[:10].plot.bar(x='Major',y='Unemployment_rate')

# %%
last10_unemp = recent_grads[-11:-1].plot.bar(x='Major',y='Unemployment_rate')

# %% [markdown]
# ## Exploration

# %%
top10_men_women = recent_grads[:10].plot.bar(x='Major',y=['Men','Women'])

# %%
last10_men_women = recent_grads[-11:-1].plot.bar(x='Major',y=['Men','Women'])

# %% [markdown]
# ## Exploration
#
# The last two bar plots are comparing the number of women and men in the _Top Ten_ and _Last Ten_ majors (ranked by median salary). These comparisons provide an understanding of the gender imbalance within academia, as well as the higher paying industries. Clearly, the ten highest median-salary jobs have a very low female representation and the ten lowest median-salary jobs,
